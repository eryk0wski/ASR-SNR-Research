# %%
#Authorization to the huggingface

from huggingface_hub import notebook_login

notebook_login()

# %%
from src.data_engineering import creating_random_split_df, audio_normalizer
from src.model_training import prepare_dataset, compute_metrics, DataCollatorSpeechSeq2SeqWithPadding, WhisperTokenizer

# %%
model_id = "openai/whisper-medium"

# %%
tokenizer = WhisperTokenizer.from_pretrained(model_id, language="polish", task="transcribe")
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
tokenizer.push_to_hub("whisper-med-pol-car-2500")
# Out:
# CommitInfo(commit_url='https://huggingface.co/eryk7381/whisper-med-pol-car-2500/commit/4487bd22564812a8a49edb4977590645f23476bc', commit_message='Upload tokenizer', commit_description='', oid='4487bd22564812a8a49edb4977590645f23476bc', pr_url=None, pr_revision=None, pr_num=None)
