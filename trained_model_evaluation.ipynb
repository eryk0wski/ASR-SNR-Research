# %%
import pandas as pd
from jiwer import wer
import matplotlib.pyplot as plt 
from src.data_plotting import histogram_plotting, boxplot_plotting, kde_plotting, plot_model_comparison
from src.statistics import advanced_statistics, word_frequency

# %%
df = pd.read_parquet('./data/parquets/trained_results_newest.parquet.gzip')

# %%
df.columns
# Out:
# Index(['audioname', 'dataset', 'ref_orig', 'sampling_rate', 'audiopath_bigos',
#        'audiopath_local', 'noise_path', 'noise_class', 'normalised_audio_path',
#        'normalised_noise_path', 'audio_SNR_100_path', 'audio_SNR_50_path',
#        'audio_SNR_25_path', 'audio_SNR_10_path', 'audio_SNR_5_path',
#        'audio_SNR_0.1_path', 'audio_SNR_-1_path', 'audio_SNR_-3_path',
#        'audio_SNR_-10_path', 'snr_25_testing_trained', 'SNR25_models_testing',
#        'model15k', 'model2_5k', 'model10k', 'model3_5k'],
#       dtype='object')

# %%
model_stats = advanced_statistics(df,'model','ref_orig',5)

# %%
model_stats
# Out:
#                        WER_SNR_15k  WER_SNR_2_5k  WER_SNR_10k  WER_SNR_3_5k
# count                      2500.00       2500.00      2500.00       2500.00
# mean                         13.25         13.94        11.63         14.11
# std                          19.79         19.13        18.88         19.77
# min                           0.00          0.00         0.00          0.00
# 25%                           0.00          0.00         0.00          0.00
# 50%                           9.38         10.00         7.69         10.34
# 75%                          18.18         20.00        16.67         20.00
# max                         500.00        500.00       480.00        480.00
# mean without 2%              10.48         11.24         9.07         11.19
# Perfect outputs             699.00        636.00       800.00        643.00
# Very good outputs           575.00        578.00       607.00        530.00
# Acceptable outputs          644.00        647.00       601.00        691.00
# Acceptable percentage        79.32         77.40        82.84         77.20
