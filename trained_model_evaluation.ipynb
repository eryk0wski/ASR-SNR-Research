# %%
import pandas as pd
from jiwer import wer
import matplotlib.pyplot as plt 
from src.data_plotting import histogram_plotting, boxplot_plotting, kde_plotting, plot_model_comparison
from src.statistics import advanced_statistics, word_frequency

# %%
df = pd.read_parquet('./data/parquets/training_evaluation_results.parquet.gzip')

# %%
df.columns
# Out:
# Index(['transcription', 'SNR_25_model_no_train', 'SNR_25_model2_5k',
#        'SNR_25_model3_5k', 'SNR_25_model10k', 'SNR_25_model15k',
#        'SNR_50_model2_5k', 'SNR_50_model3_5k', 'SNR_50_model10k',
#        'SNR_50_model15k', 'SNR_50_model35k', 'SNR_10_model2_5k',
#        'SNR_10_model3_5k', 'SNR_10_model10k', 'SNR_10_model15k',
#        'SNR_10_model35k', 'SNR_25_whisper_medium', 'SNR_5_whisper_medium',
#        'SNR_5_model2_5k', 'SNR_5_model3_5k', 'SNR_5_model10k',
#        'SNR_5_model15k', 'SNR_5_model35k', 'SNR_5_model80k', 'SNR_25_model35k',
#        'SNR_25_model80k', 'SNR_10_model80k', 'SNR_100_model2_5k',
#        'SNR_100_model3_5k', 'SNR_100_model10k', 'SNR_100_model15k',
#        'SNR_100_model35k', 'SNR_100_model80k', 'SNR_50_model80k',
#        'SNR_50_whisper_medium', 'SNR_10_whisper_medium'],
#       dtype='object')

# %%
model_stats = advanced_statistics(data = df,column_prefix='SNR_25',sentences_column='transcription',proc_outliers=2)

# %%
model_stats
# Out:
#                        Model_SNR_whisper_medium  Model_SNR_model2_5k  \
# count                                   2500.00              2500.00
# mean                                      12.79                11.28
# std                                       23.17                17.70
# min                                        0.00                 0.00
# 25%                                        0.00                 0.00
# 50%                                        8.70                 7.69
# 75%                                       17.65                16.67
# max                                      600.00               500.00
# mean without 2%                           10.72                 9.85
# Perfect outputs                          825.00               827.00
# Very good outputs                        505.00               589.00
# Acceptable outputs                       637.00               607.00
# Acceptable percentage                     80.96                82.96
#
#                        Model_SNR_model3_5k  Model_SNR_model10k  \
# count                              2500.00             2500.00
# mean                                 11.47                9.41
# std                                  18.46               17.62
# min                                   0.00                0.00
# 25%                                   0.00                0.00
# 50%                                   8.14                5.88
# 75%                                  16.23               13.68
# max                                 480.00              480.00
# mean without 2%                       9.89                7.98
# Perfect outputs                     822.00              992.00
# Very good outputs                   555.00              601.00
# Acceptable outputs                  654.00              534.00
# Acceptable percentage                83.40               87.00
#
#                        Model_SNR_model15k  Model_SNR_model35k  \
# count                             2500.00             2500.00
# mean                                10.69               18.48
# std                                 18.57               23.34
# min                                  0.00                0.00
# 25%                                  0.00                2.86
# 50%                                  7.14               13.33
# 75%                                 15.38               27.09
# max                                500.00              560.00
# mean without 2%                      9.12               16.71
# Perfect outputs                    900.00              598.00
# Very good outputs                  581.00              409.00
# Acceptable outputs                 585.00              573.00
# Acceptable percentage               84.80               65.80
#
#                        Model_SNR_model80k  Model_SNR_model_no_train
# count                             2500.00                   2500.00
# mean                                18.60                    122.20
# std                                 25.46                     57.90
# min                                  0.00                      0.00
# 25%                                  0.00                    108.33
# 50%                                 13.33                    121.05
# 75%                                 26.67                    133.33
# max                                540.00                   2520.00
# mean without 2%                     16.50                    121.70
# Perfect outputs                    632.00                     38.00
# Very good outputs                  392.00                      7.00
# Acceptable outputs                 544.00                     15.00
# Acceptable percentage               65.68                      2.44

# %%
print(df[['transcription', 'SNR_25_model10k', 'SNR_25_whisper_medium']])
# Out:
#                                           transcription  \
# 0     tam nocne włóczęgi wołano z dachów jeżeli nie ...
# 1     w  pracy  studenci  chcieliby  przede  wszystk...
# 2     co to znaczy sam siebie zapytywał faraon czy g...
# 3     tylko na piaszczystem wybrzeżu lub na łąkach b...
# 4     zaokrągla  uziemienie  księdzu  liźnięcie  rol...
# ...                                                 ...
# 2495  kazał zrobić spis wszystkich mężczyzn w państw...
# 2496  W odniesieniu do Lizbony, uczyniliśmy także po...
# 2497     Jej budżet to budżet, który wspiera inwestycje
# 2498  upłynęło już kilka godzin po zachodzie słońca ...
# 2499  Prywatyzacja usług publicznych i społecznych r...
#
#                                         SNR_25_model10k  \
# 0     wej wy tam nocne marki wołano z dachów jeżeli ...
# 1     pracy  studenci  chcieliby  przede  wszystkim ...
# 2     co to znaczy sam siebie zapytywał faraon czy g...
# 3     tylko na piaszczystym wybrzeżu lub na łąkach b...
# 4     zaokrągla  uziemienie  księdzu  liźnięcie  rol...
# ...                                                 ...
# 2495  kazał zrobić spis wszystkich mężczyzn państwie...
# 2496  W odniesieniu do Lizbony, uczyniliśmy także po...
# 2497     Jej budżet to budżet, który wspiera inwestycje
# 2498  upłynęło już kilka godzin po zachodzie słońca ...
# 2499  Pywatyzacja usług publicznych i społecznych ró...
#
#                                   SNR_25_whisper_medium
# 0      Hej, witam, nocne Marki! Wołano z dachów. Jeż...
# 1      Pracy studenci chcieliby przede wszystkim odc...
# 2      Co to znaczy? – sam siebie zapytywał Faraon. ...
# 3      Tylko na piaszczystym wybrzeżu lub na łąkach ...
# 4      Zaokrągla, uziemienie, księdzu, liźnięcie, ro...
# ...                                                 ...
# 2495   Kazał zrobić spis wszystkich mężczyzn państwi...
# 2496   W odniesieniu do Lisbony uczyniliśmy także po...
# 2497    Jej budżet to budżet, który wspiera inwestycje.
# 2498   Upłynęło już kilka godzin po zachodzie słońca...
# 2499   Prywatyzacja usług publicznych i społecznych ...
#
# [2500 rows x 3 columns]

# %%
df.to_csv("csv_parquet_converted_snr_25.csv")
